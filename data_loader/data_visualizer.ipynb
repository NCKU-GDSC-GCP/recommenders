# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# ## train_full.csv

# %%
data_train_full = pd.read_csv("dataset/train_full.csv", low_memory=False)
data_train_full.head()
# Out:
#   customer_id gender  status_x  verified_x         created_at_x  \
# 0     TCHWPBT   Male         1           1  2018-02-07 19:16:23
# 1     TCHWPBT   Male         1           1  2018-02-07 19:16:23
# 2     TCHWPBT   Male         1           1  2018-02-07 19:16:23
# 3     TCHWPBT   Male         1           1  2018-02-07 19:16:23
# 4     TCHWPBT   Male         1           1  2018-02-07 19:16:23
#
#           updated_at_x  location_number location_type  latitude_x  \
# 0  2018-02-07 19:16:23                0          Work      -96.44
# 1  2018-02-07 19:16:23                0          Work      -96.44
# 2  2018-02-07 19:16:23                0          Work      -96.44
# 3  2018-02-07 19:16:23                0          Work      -96.44
# 4  2018-02-07 19:16:23                0          Work      -96.44
#
#    longitude_x  ...  country_id  city_id         created_at_y  \
# 0        -67.2  ...         1.0      1.0  2018-01-30 14:42:04
# ...

# %%
data_train_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5802400 entries, 0 to 5802399
# Data columns (total 73 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   customer_id             object
#  1   gender                  object
#  2   status_x                int64
#  3   verified_x              int64
#  4   created_at_x            object
#  5   updated_at_x            object
#  6   location_number         int64
#  7   location_type           object
#  8   latitude_x              float64
#  9   longitude_x             float64
#  10  id                      int64
#  11  authentication_id       float64
#  12  latitude_y              float64
#  13  longitude_y             float64
#  14  vendor_category_en      object
#  15  vendor_category_id      float64
#  16  delivery_charge         float64
#  17  serving_distance        float64
#  18  is_open                 float64
#  19  OpeningTime             object
#  20  OpeningTime2            object
# ...

# %%
msno.matrix(data_train_full)
# Out:
# <AxesSubplot:>

# %%
print(data_train_full["gender"].value_counts())
gender_null = np.count_nonzero(data_train_full['gender'].isnull())
print(gender_null)
gender_null / data_train_full.shape[0]
# Out:
# Male      3789100
# Female     308200
# Name: gender, dtype: int64
# 1705100
# 0.2938611608989384

# %%
sns.countplot("gender", data=data_train_full)
# Out:
# c:\Users\Yeh\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
print(data_train_full["location_type"].value_counts())
location_null = np.count_nonzero(data_train_full["location_type"].isnull())
print(location_null)

print("null ratio: ", location_null / data_train_full.shape[0])
# Out:
# Home     1921700
# Work      627400
# Other     599100
# Name: location_type, dtype: int64
# 2654200
# null ratio:  0.45743140769336826

# %%
sns.countplot("location_type", data=data_train_full)
# Out:
# c:\Users\Yeh\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='location_type', ylabel='count'>

# %%
sns.countplot(data_train_full["gender"], hue=data_train_full["location_type"])
# Out:
# c:\Users\Yeh\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
print(data_train_full["language"].value_counts())
language_null = np.count_nonzero(data_train_full["language"].isnull())
print(language_null)

language_null / data_train_full.shape[0]
# Out:
# EN    4932040
# Name: language, dtype: int64
# 870360
# 0.15

# %%
openingTime_null = np.count_nonzero(data_train_full["OpeningTime"].isnull())
print(openingTime_null)

openingTime_null / data_train_full.shape[0]
# Out:
# 522216
# 0.09

# %%
print(data_train_full["vendor_rating"].value_counts())
rating_null = np.count_nonzero(data_train_full["vendor_rating"].isnull())
print(rating_null)

rating_null / data_train_full.shape[0]
# Out:
# 4.5    1102456
# 4.3    1044432
# 4.2     870360
# 4.4     812336
# 4.6     580240
# 4.7     406168
# 4.0     348144
# 4.1     290120
# 3.8     116048
# 4.8     116048
# 3.2      58024
# 3.7      58024
# Name: vendor_rating, dtype: int64
# 0
# 0.0

# %%
sns.countplot("vendor_rating", data=data_train_full)
# Out:
# c:\Users\Yeh\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='vendor_rating', ylabel='count'>

# %% [markdown]
# ## orders.csv

# %%
data_orders = pd.read_csv("dataset/orders.csv", low_memory=False)
data_orders.head()
# Out:
#    akeed_order_id customer_id  item_count  grand_total  payment_mode  \
# 0        163238.0     92PEE24         1.0          7.6             2
# 1        163240.0     QS68UD8         1.0          8.7             1
# 2        163241.0     MB7VY5F         2.0         14.4             1
# 3        163244.0     KDJ951Y         1.0          7.1             1
# 4        163245.0     BAL0RVT         4.0         27.2             1
#
#   promo_code  vendor_discount_amount  promo_code_discount_percentage  \
# 0        NaN                     0.0                             NaN
# 1        NaN                     0.0                             NaN
# 2        NaN                     0.0                             NaN
# 3        NaN                     0.0                             NaN
# 4        NaN                     0.0                             NaN
#
#   is_favorite is_rated  ...  driver_accepted_time  ready_for_pickup_time  \
# ...

# %%
data_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135303 entries, 0 to 135302
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   akeed_order_id                  135233 non-null  float64
#  1   customer_id                     135303 non-null  object
#  2   item_count                      128378 non-null  float64
#  3   grand_total                     135303 non-null  float64
#  4   payment_mode                    135303 non-null  int64
#  5   promo_code                      4305 non-null    object
#  6   vendor_discount_amount          135303 non-null  float64
#  7   promo_code_discount_percentage  65880 non-null   float64
#  8   is_favorite                     100108 non-null  object
#  9   is_rated                        135303 non-null  object
#  10  vendor_rating                   45220 non-null   float64
# ...

# %%
print(data_orders["vendor_rating"].value_counts())
rating_null = np.count_nonzero(data_orders["vendor_rating"].isnull())
print(rating_null)

rating_null / data_orders.shape[0]
# Out:
# 0.0    25175
# 5.0    14212
# 4.0     2748
# 3.0     1426
# 1.0     1029
# 2.0      630
# Name: vendor_rating, dtype: int64
# 90083
# 0.6657871591908531

# %%
sns.countplot("vendor_rating", data=data_orders)
# Out:
# c:\Users\Yeh\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='vendor_rating', ylabel='count'>

# %%
print(data_orders["vendor_id"].value_counts())
# Out:
# 113    7807
# 105    5562
# 79     5117
# 84     5001
# 78     4643
#        ...
# 304     562
# 271     559
# 196     512
# 250     503
# 295     474
# Name: vendor_id, Length: 100, dtype: int64

# %%
print(data_orders["customer_id"].value_counts())
# Out:
# XW90EAP    262
# TL7Z2DM    151
# VDEJEMP    146
# HJFTTGW    128
# B28LJKM    119
#           ...
# B6DEG8Q      1
# FP47TR0      1
# NIIOLY3      1
# 1WM7MLN      1
# QDXLWM7      1
# Name: customer_id, Length: 27445, dtype: int64
